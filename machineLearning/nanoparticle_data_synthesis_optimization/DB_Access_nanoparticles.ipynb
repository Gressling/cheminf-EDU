# %%
# %%capture
# !pip install PyMySQL
import pymysql.cursors
import pandas as pd
import warnings
import getpass
warnings.filterwarnings('ignore')

# %%
def connect():
    # database credentials
    host = input("Enter database host: ")
    db= input("Enter database name: ")
    usr = input("Enter database user: ")
    pwd = getpass.getpass("Enter database password: ")


    # connect to the database
    try:
        return pymysql.connect(host=host, user=usr, password=pwd, database=db,
            cursorclass=pymysql.cursors.DictCursor)
    except pymysql.Error as err:
        print("error %d: %s" %(err.args[0], err.args[1]))
        return ""

# %%
def query_table(table_name):
    sql = f"SELECT * FROM {table_name};"

    # connect to database
    db_connection = connect()

    # check connection
    if not (type(db_connection) == str):
        # execute query and fetch results
        with db_connection.cursor() as cursor:
            cursor.execute(sql)
            result = cursor.fetchall()
        return result
    else:
        return []

# Call the function to query the table
results = query_table('r18_nanoparticle_experiments')



df = pd.DataFrame(results)
df.head(10)
# Out:
# Enter database host: den1.mysql6.gear.host
# Enter database name: situation
# Enter database user: situation
# Enter database password: ··········
#    id  temperature  pressure  time  reactant_A_concentration  \
# 0   1        300.0       1.5   2.5                       0.8
# 1   2        320.0       1.7   3.0                       0.7
# 2   3        310.0       1.8   2.7                       0.9
# 3   4        305.0       1.6   2.8                       0.6
# 4   5        315.0       1.9   3.2                       0.8
# 5   6        325.0       1.5   2.9                       0.7
# 6   7        295.0       1.4   2.6                       0.6
# 7   8        310.0       1.7   3.1                       0.9
# 8   9        300.0       1.6   2.8                       0.8
# 9  10        315.0       1.8   3.0                       0.7
#
#    reactant_B_concentration  reactant_C_concentration  particle_size
# 0                       0.6                       0.4           50.0
# 1                       0.5                       0.3           55.0
# 2                       0.4                       0.2           48.0
# 3                       0.7                       0.5           52.0
# 4                       0.8                       0.6           60.0
# 5                       0.6                       0.4           45.0
# 6                       0.5                       0.3           47.0
# 7                       0.6                       0.4           53.0
# 8                       0.7                       0.5           58.0
# 9                       0.5                       0.3           49.0
