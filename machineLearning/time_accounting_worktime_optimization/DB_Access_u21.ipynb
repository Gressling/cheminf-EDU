# %%
# !pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.1.0

# %%
import pymysql.cursors

# %%
host = 'den1.mysql6.gear.host'
db = 'situation'
usr = 'situation'
psword = input()

# Connect to the database
connection = pymysql.connect(host=host, user=usr, password=psword, database=db, cursorclass=pymysql.cursors.DictCursor)
# Out:
# cogni88.

# %%
import pandas as pd

# %%
#UserId = 'SomeDeviceName'
sql = "SELECT * FROM u21_labtimeaccountingrl"

with connection.cursor() as cursor:
   cursor.execute(sql)
   df_raw = pd.DataFrame(data=cursor.fetchall(), index= None)

# %%
df_raw.head(10)
# Out:
#    ExperimentID  TaskID TaskDescription           StartTime  \
# 0           144       2        cleaning 2024-01-01 09:00:00
# 1           147       4        benchtop 2024-01-01 10:00:00
# 2           164       1       precursor 2024-01-01 11:00:00
# 3           167       4        benchtop 2024-01-01 12:00:00
# 4           167       3       analytics 2024-01-01 13:00:00
# 5           109       1       precursor 2024-01-01 14:00:00
# 6           183       4        cleaning 2024-01-01 15:00:00
# 7           121       4       precursor 2024-01-01 16:00:00
# 8           136       3       analytics 2024-01-01 17:00:00
# 9           187       4       precursor 2024-01-01 18:00:00
#
#               EndTime  TotalTime  Reward ExperimentGroup
# 0 2024-01-01 09:30:00        161      14   Ethylvanillin
# 1 2024-01-01 10:30:00        128       5   Ethylvanillin
# 2 2024-01-01 11:30:00         72       8        Guaiacol
# 3 2024-01-01 12:30:00        142       5  ortho-Vanillin
# 4 2024-01-01 13:30:00        179       1  ortho-Vanillin
# 5 2024-01-01 14:30:00        157      28  ortho-Vanillin
# 6 2024-01-01 15:30:00         30      39  ortho-Vanillin
# 7 2024-01-01 16:30:00        168      -9   Ethylvanillin
# 8 2024-01-01 17:30:00        144      21   Ethylvanillin
# 9 2024-01-01 18:30:00         73      14  ortho-Vanillin
