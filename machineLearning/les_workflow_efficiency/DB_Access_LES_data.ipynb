# %%
# !pip install PyMySQL
# https://github.com/PyMySQL/PyMySQL/

# %%
import pymysql.cursors
import warnings
import pandas as pd
warnings.filterwarnings('ignore')

# %%
def connect():
    # database credentials
    host = 'den1.mysql6.gear.host'
    db = 'situation'
    usr = 'situation'
    pwd = input()

    # connect to the database
    try: 
        return pymysql.connect(host=host, user=usr, password=pwd, database=db, 
            cursorclass=pymysql.cursors.DictCursor)
    except pymysql.Error as err:
        print("error %d: %s" %(err.args[0], err.args[1]))
        return ""

# %%
def get_tables(selected):
    # query all tables in database
    sql = "show tables;"
    retval = []

    # connect to database
    dbConnection = connect()

    # check for type, if not str proceed
    if not (type(dbConnection) == str):
        # execute query via cursor, fetch all data
        with dbConnection.cursor() as cursor:
          cursor.execute(sql)
          result = cursor.fetchall()

        # now try to find tables with parameter selected in name
        # and append to list
        for count in range(0, len(result)):
            for (key, value) in result[count].items():
                if (value.find(selected) != -1):
                    print(value)
                    retval.append(value)
    
    # return list
    return retval

# %%
def describe_table(myTable):
    sql = "describe " + myTable + ";"
    
    # connect to database
    dbConnection = connect()
    
    # check for type, if not str proceed
    if not (type(dbConnection) == str):
        # execute query via cursor, fetch all data
        with dbConnection.cursor() as cursor:
            cursor.execute(sql)
            result = cursor.fetchall()
        
        # now try to describe the table
        for count in range(0, len(result)):
            for (key, value) in result[count].items():
                print(key ,":", value, "; ", end="")
            print("")

# %%
tables = get_tables("f6")
print(tables)

for table in tables:
    describe_table(table)
    display(pd.read_sql("select * from " + table + ";", connect()))
# Out:
# f6_entity
# f6_laboratorytasks
# f6_les_workflow
# f6_workflow_step_chemicals
# f6_workflow_step_devices
# ['f6_entity', 'f6_laboratorytasks', 'f6_les_workflow', 'f6_workflow_step_chemicals', 'f6_workflow_step_devices']
# Field : Step_ID ; Type : int(11) ; Null : NO ; Key : PRI ; Default : None ; Extra :  ;
# Field : Workflow_ID ; Type : int(11) ; Null : YES ; Key : MUL ; Default : None ; Extra :  ;
# Field : Unit_Operation_ID ; Type : int(11) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : Predecessor_ID ; Type : int(11) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : Successor_ID ; Type : int(11) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : step_name ; Type : varchar(255) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : description ; Type : varchar(255) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : step_param ; Type : varchar(255) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
#     Step_ID  Workflow_ID Unit_Operation_ID  Predecessor_ID  Successor_ID  \
# 0         1            1              None             NaN           2.0
# 1         2            1              None             1.0           3.0
# 2         3            1              None             2.0           4.0
# 3         4            1              None             3.0           5.0
# 4         5            1              None             4.0           6.0
# 5         6            1              None             5.0           7.0
# 6         7            1              None             6.0           8.0
# 7         8            1              None             7.0           9.0
# 8         9            1              None             8.0          10.0
# 9        10            1              None             9.0          11.0
# 10       11            1              None            10.0          12.0
# 11       12            1              None            11.0          13.0
# 12       13            1              None            12.0          14.0
# 13       14            1              None            13.0           NaN
# 14       15            2              None             NaN          16.0
# 15       16            2              None            15.0          17.0
# 16       17            2              None            16.0          18.0
# 17       18            2              None            17.0          19.0
# 18       19            2              None            18.0          20.0
# 19       20            2              None            19.0          21.0
# 20       21            2              None            20.0          22.0
# 21       22            2              None            21.0          23.0
# 22       23            2              None            22.0          24.0
# 23       24            2              None            23.0          25.0
# 24       25            2              None            24.0          26.0
# 25       26            2              None            25.0          27.0
# 26       27            2              None            26.0          28.0
# 27       28            2              None            27.0           NaN
#
#                       step_name  \
# 0            Safety Precautions
# 1        Materials and Reagents
# 2           Weighing and Mixing
# 3                Reaction Setup
# 4          Heating and Reaction
# 5   Cooling and Crystallization
# 6                    Filtration
# 7            Washing and Drying
# 8               Data Collection
# 9              Characterization
# 10                      Cleanup
# 11                Documentation
# 12    Safety and Waste Disposal
# 13      Analysis and Discussion
# 14           Safety Precautions
# 15       Materials and Reagents
# 16          Weighing and Mixing
# 17               Reaction Setup
# 18         Heating and Reaction
# 19    Cooling and Precipitation
# 20                   Filtration
# 21           Washing and Drying
# 22              Data Collection
# 23             Characterization
# 24                      Cleanup
# 25                Documentation
# 26    Safety and Waste Disposal
# 27      Analysis and Discussion
#
#                                           description  \
# 0   Put on appropriate PPE and ensure proper venti...
# 1            Gather necessary materials and reagents.
# 2   Weigh and mix salicylic acid and acetic anhydr...
# 3   Place the flask in a water bath and add sulfur...
# 4                 Heat the mixture in the water bath.
# 5    Allow the flask to cool and add distilled water.
# 6             Set up a Buchner funnel for filtration.
# 7                  Wash and dry the aspirin crystals.
# 8        Record mass and appearance, calculate yield.
# 9   Use techniques for identity and purity confirm...
# 10              Dispose of waste and clean equipment.
# 11           Record all data in a notebook or report.
# 12           Dispose of chemicals and waste properly.
# 13     Analyze results and discuss synthesis success.
# 14  Wear appropriate PPE and ensure proper ventila...
# 15           Gather necessary materials and reagents.
# 16      Weigh and mix copper oxide and sulfuric acid.
# 17          Place the beaker on a stirring hot plate.
# 18                   Heat the mixture while stirring.
# 19          Let the mixture cool to room temperature.
# 20                 Set up a vacuum filtration system.
# 21  Wash and dry the copper sulfate pentahydrate c...
# 22       Record mass and appearance, calculate yield.
# 23  Use techniques for identity and purity confirm...
# 24              Dispose of waste and clean equipment.
# 25           Record all data in a notebook or report.
# 26           Dispose of chemicals and waste properly.
# 27     Analyze results and discuss synthesis success.
#
#                               step_param
# 0                      Safety parameters
# 1                   Materials parameters
# 2                    Weighing parameters
# 3              Reaction setup parameters
# 4                     Heating parameters
# 5                     Cooling parameters
# 6                  Filtration parameters
# 7                     Washing parameters
# 8             Data collection parameters
# 9            Characterization parameters
# 10                    Cleanup parameters
# 11              Documentation parameters
# 12  Safety and waste disposal parameters
# 13    Analysis and discussion parameters
# 14                     Safety parameters
# 15                  Materials parameters
# 16                   Weighing parameters
# 17             Reaction setup parameters
# 18                    Heating parameters
# 19                    Cooling parameters
# 20                 Filtration parameters
# 21                    Washing parameters
# 22            Data collection parameters
# 23           Characterization parameters
# 24                    Cleanup parameters
# 25              Documentation parameters
# 26  Safety and waste disposal parameters
# 27    Analysis and discussion parameters
# Field : TaskID ; Type : int(11) ; Null : NO ; Key : PRI ; Default : None ; Extra : auto_increment ;
# Field : TaskStatus ; Type : enum('pending','in-progress','completed') ; Null : NO ; Key :  ; Default : None ; Extra :  ;
# Field : ResourceAllocated ; Type : varchar(255) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : TimeSpent ; Type : decimal(5,2) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : Reward ; Type : decimal(5,2) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : Timestamp ; Type : timestamp ; Null : NO ; Key :  ; Default : CURRENT_TIMESTAMP ; Extra : on update CURRENT_TIMESTAMP ;
#     TaskID   TaskStatus ResourceAllocated  TimeSpent  Reward  \
# 0        1      pending         Resource1        0.0     0.0
# 1        2  in-progress         Resource2        1.5     0.5
# 2        3    completed         Resource3        2.0     1.0
# 3        4      pending         Resource4        2.5     1.5
# 4        5  in-progress         Resource5        3.0     2.0
# 5        6    completed         Resource1        0.0     0.0
# 6        7      pending         Resource2        1.5     0.5
# 7        8  in-progress         Resource3        2.0     1.0
# 8        9    completed         Resource4        2.5     1.5
# 9       10      pending         Resource5        3.0     2.0
# 10      11  in-progress         Resource1        0.0     0.0
# 11      12    completed         Resource2        1.5     0.5
# 12      13      pending         Resource3        2.0     1.0
# 13      14  in-progress         Resource4        2.5     1.5
# 14      15    completed         Resource5        3.0     2.0
# 15      16      pending         Resource1        0.0     0.0
# 16      17  in-progress         Resource2        1.5     0.5
# 17      18    completed         Resource3        2.0     1.0
# 18      19      pending         Resource4        2.5     1.5
# 19      20  in-progress         Resource5        3.0     2.0
# 20      21    completed         Resource1        0.0     0.0
# 21      22      pending         Resource2        1.5     0.5
# 22      23  in-progress         Resource3        2.0     1.0
# 23      24    completed         Resource4        2.5     1.5
# 24      25      pending         Resource5        3.0     2.0
# 25      26  in-progress         Resource1        0.0     0.0
# 26      27    completed         Resource2        1.5     0.5
# 27      28      pending         Resource3        2.0     1.0
# 28      29  in-progress         Resource4        2.5     1.5
# 29      30    completed         Resource5        3.0     2.0
# 30      31      pending         Resource1        0.0     0.0
# 31      32  in-progress         Resource2        1.5     0.5
# 32      33    completed         Resource3        2.0     1.0
# 33      34      pending         Resource4        2.5     1.5
# 34      35  in-progress         Resource5        3.0     2.0
# 35      36    completed         Resource1        0.0     0.0
# 36      37      pending         Resource2        1.5     0.5
# 37      38  in-progress         Resource3        2.0     1.0
# 38      39    completed         Resource4        2.5     1.5
#
#              Timestamp
# 0  2024-05-12 08:28:45
# 1  2024-05-12 08:28:48
# 2  2024-05-12 08:28:50
# 3  2024-05-12 08:28:52
# 4  2024-05-12 08:28:54
# 5  2024-05-12 08:28:56
# 6  2024-05-12 08:28:58
# 7  2024-05-12 08:29:01
# 8  2024-05-12 08:29:03
# 9  2024-05-12 08:29:05
# 10 2024-05-12 08:29:07
# 11 2024-05-12 08:29:10
# 12 2024-05-12 08:29:12
# 13 2024-05-12 08:29:14
# 14 2024-05-12 08:29:16
# 15 2024-05-12 08:29:18
# 16 2024-05-12 08:29:20
# 17 2024-05-12 08:29:22
# 18 2024-05-12 08:29:23
# 19 2024-05-12 08:29:25
# 20 2024-05-12 08:29:27
# 21 2024-05-12 08:29:29
# 22 2024-05-12 08:29:31
# 23 2024-05-12 08:29:33
# 24 2024-05-12 08:29:35
# 25 2024-05-12 08:29:37
# 26 2024-05-12 08:29:39
# 27 2024-05-12 08:29:41
# 28 2024-05-12 08:29:44
# 29 2024-05-12 08:29:46
# 30 2024-05-12 08:29:48
# 31 2024-05-12 08:29:50
# 32 2024-05-12 08:29:53
# 33 2024-05-12 08:29:55
# 34 2024-05-12 08:29:57
# 35 2024-05-12 08:30:00
# 36 2024-05-12 08:30:02
# 37 2024-05-12 08:30:04
# 38 2024-05-12 08:30:07
# Field : Workflow_ID ; Type : int(11) ; Null : NO ; Key : PRI ; Default : None ; Extra :  ;
# Field : Workflow_Name ; Type : varchar(255) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : Description ; Type : varchar(255) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
#    Workflow_ID                          Workflow_Name  \
# 0            1                      Aspirin Synthesis
# 1            2  Copper Sulfate Pentahydrate Synthesis
#
#                                          Description
# 0             Aspirin synthesis workflow description
# 1  Copper sulfate pentahydrate synthesis workflow...
# Field : Workflow_Chemicals_ID ; Type : int(11) ; Null : NO ; Key : PRI ; Default : None ; Extra :  ;
# Field : Chemical_ID ; Type : int(11) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : Step_ID ; Type : int(11) ; Null : YES ; Key : MUL ; Default : None ; Extra :  ;
# Field : Predecessor_ID ; Type : int(11) ; Null : YES ; Key : MUL ; Default : None ; Extra :  ;
# Field : Successor_ID ; Type : int(11) ; Null : YES ; Key : MUL ; Default : None ; Extra :  ;
# Field : amount ; Type : varchar(255) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
#     Workflow_Chemicals_ID  Chemical_ID  Step_ID Predecessor_ID Successor_ID  \
# 0                       1          101        3           None         None
# 1                       2          102        3           None         None
# 2                       3          103        3           None         None
# 3                       4          104        4           None         None
# 4                       5          105        5           None         None
# 5                       6          106        6           None         None
# 6                       7          107        6           None         None
# 7                       8          108        7           None         None
# 8                       9          109        8           None         None
# 9                      10          110        9           None         None
# 10                     11          111        9           None         None
# 11                     12          112        9           None         None
# 12                     13          113       10           None         None
# 13                     14          114       11           None         None
#
#       amount
# 0   10 grams
# 1    5 grams
# 2    2 grams
# 3      15 mL
# 4        N/A
# 5      50 mL
# 6     100 mL
# 7        N/A
# 8        N/A
# 9      20 mL
# 10     50 mL
# 11       N/A
# 12       N/A
# 13       N/A
# Field : Workflow_Devices_ID ; Type : int(11) ; Null : NO ; Key : PRI ; Default : None ; Extra :  ;
# Field : Device_ID ; Type : int(11) ; Null : YES ; Key :  ; Default : None ; Extra :  ;
# Field : Step_ID ; Type : int(11) ; Null : YES ; Key : MUL ; Default : None ; Extra :  ;
# Field : Predecessor_ID ; Type : int(11) ; Null : YES ; Key : MUL ; Default : None ; Extra :  ;
# Field : Successor_ID ; Type : int(11) ; Null : YES ; Key : MUL ; Default : None ; Extra :  ;
#     Workflow_Devices_ID  Device_ID  Step_ID Predecessor_ID Successor_ID
# 0                     1        201        4           None         None
# 1                     2        202        5           None         None
# 2                     3        203        5           None         None
# 3                     4        204        7           None         None
# 4                     5        205        9           None         None
# 5                     6        206       10           None         None
# 6                     7        207       12           None         None
# 7                     8        208       13           None         None
# 8                     9        209       14           None         None
# 9                    10        210       14           None         None
# 10                   11        211       14           None         None
# 11                   12        212       14           None         None
# 12                   13        213       14           None         None
# 13                   14        214       14           None         None
