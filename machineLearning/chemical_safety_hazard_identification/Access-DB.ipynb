# %% [markdown]
# ### <ins>Notebook to read DB data and save as pandas.DataFrame</ins>

# %% [markdown]
# ##### Imports:

# %%
from sqlalchemy import create_engine, text
import pandas as pd
from dotenv import load_dotenv
import os

# %% [markdown]
# ##### Load Credentials:

# %%
# .env file path
env_path = os.path.join("env", "credentials.env")

# Load .env file
load_dotenv(dotenv_path=env_path)

# Call credentials
db_host = os.getenv("DB_HOST")
db_name = os.getenv("DB_NAME")
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")

# %% [markdown]
# ##### Connect to DB and save as .parquet file

# %%
db_url = f"mysql+mysqldb://{db_user}:{db_password}@{db_host}/{db_name}"

engine = create_engine(db_url)

query = text("SELECT * FROM situation.m13_chemicalsafetydata")

# Save path for CSV and parquet files
save_path_parquet = "data/chemicalsafetydata.parquet"
save_path_csv = "data/chemicalsafetydata.csv"


try:
    with engine.connect() as connection:
        
        result = connection.execute(query)

        df = pd.DataFrame(result.fetchall(), columns=result.keys())
        
        df.to_parquet(save_path_parquet)
        print(f"Data (Parquet) successfully saved in '{save_path_parquet}'")
        df.to_csv(save_path_csv, index=False)
        print(f"Data (CSV) successfully saved in '{save_path_csv}'")
        
        connection.close()
except Exception as e:
    print(f"Error: {e}")
# Out:
# Data (Parquet) successfully saved in 'data/chemicalsafetydata.parquet'
# Data (CSV) successfully saved in 'data/chemicalsafetydata.csv'

# %% [markdown]
# ##### Print DataFrame:

# %%
data = pd.read_parquet(save_path_parquet, engine="fastparquet")
data.head(15)
# Out:
#     ID Chemical_Name CAS_Number Physical_State Chemical_Family Toxicity_Level  \
# 0    1    Chemical A    75-07-0          Solid            Acid         Medium
# 1    2    Chemical B    75-07-0         Liquid           Ester           High
# 2    3    Chemical A    75-07-0            Gas            Acid         Medium
# 3    4    Chemical B    64-17-5            Gas            Acid         Medium
# 4    5    Chemical B    64-17-5         Liquid            Acid         Medium
# 5    6    Chemical C    64-17-5            Gas         Alcohol         Medium
# 6    7    Chemical A    50-00-0         Liquid         Alcohol            Low
# 7    8    Chemical C    64-17-5          Solid         Alcohol           High
# 8    9    Chemical A    75-07-0            Gas            Acid           High
# 9   10    Chemical A    50-00-0            Gas           Ester            Low
# 10  11    Chemical A    75-07-0          Solid            Acid         Medium
# ...
