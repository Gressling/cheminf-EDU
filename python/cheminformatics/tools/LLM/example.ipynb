# %%
import cheminformatics.tools.LLM.LLM as LLM

a = LLM.LLM()

a.load_molecule('CCO')

a.run()

print(a.get_results())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cheminformatics.tools.LLM.LLM as LLM
#       3 a = LLM.LLM()
#       5 a.load_molecule('CCO')
#
# ModuleNotFoundError: No module named 'cheminformatics.tools'

# %% [markdown]
# # localAI Test

# %%
from langchain_community.embeddings import LocalAIEmbeddings

# %%
# !pip install gressling --upgrade
apiKey = "<API_KEY>"
import os
os.environ["OPENAI_API_KEY"] = apiKey
os.getenv('OPENAI_API_KEY')
# Out:
# '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'

# %%
embeddings = LocalAIEmbeddings(
    openai_api_base="http://localhost:8080", model="embedding-model-name"
)

# %%
text = "This is a test document."

# %%
query_result = embeddings.embed_query(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 query_result = embeddings.embed_query(text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\langchain_community\embeddings\localai.py:332, in LocalAIEmbeddings.embed_query(self, text)
#     323 def embed_query(self, text: str) -> List[float]:
#     324     """Call out to LocalAI's embedding endpoint for embedding query text.
#     325
#     326     Args:
#    (...)
#     330         Embedding for the text.
#     331     """
# --> 332     embedding = self._embedding_func(text, engine=self.deployment)
#     333     return embedding
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\langchain_community\embeddings\localai.py:267, in LocalAIEmbeddings._embedding_func(self, text, engine)
#     263 if self.model.endswith("001"):
#     264     # See: https://github.com/openai/openai-python/issues/418#issuecomment-1525939500
#     265     # replace newlines, which can negatively affect performance.
#     266     text = text.replace("\n", " ")
# --> 267 return embed_with_retry(
#     268     self,
#     269     input=[text],
#     270     **self._invocation_params,
#     271 )["data"][0]["embedding"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\langchain_community\embeddings\localai.py:98, in embed_with_retry(embeddings, **kwargs)
#      96 def embed_with_retry(embeddings: LocalAIEmbeddings, **kwargs: Any) -> Any:
#      97     """Use tenacity to retry the embedding call."""
# ---> 98     retry_decorator = _create_retry_decorator(embeddings)
#     100     @retry_decorator
#     101     def _embed_with_retry(**kwargs: Any) -> Any:
#     102         response = embeddings.client.create(**kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\langchain_community\embeddings\localai.py:45, in _create_retry_decorator(embeddings)
#      37 max_seconds = 10
#      38 # Wait 2^x * 1 second between each retry starting with
#      39 # 4 seconds, then up to 10 seconds, then 10 seconds afterwards
#      40 return retry(
#      41     reraise=True,
#      42     stop=stop_after_attempt(embeddings.max_retries),
#      43     wait=wait_exponential(multiplier=1, min=min_seconds, max=max_seconds),
#      44     retry=(
# ---> 45         retry_if_exception_type(openai.error.Timeout)
#      46         | retry_if_exception_type(openai.error.APIError)
#      47         | retry_if_exception_type(openai.error.APIConnectionError)
#      48         | retry_if_exception_type(openai.error.RateLimitError)
#      49         | retry_if_exception_type(openai.error.ServiceUnavailableError)
#      50     ),
#      51     before_sleep=before_sleep_log(logger, logging.WARNING),
#      52 )
#
# AttributeError: module 'openai' has no attribute 'error'
